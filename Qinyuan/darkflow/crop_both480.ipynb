# %%
#Formal crop-newRight (0-480,0-480)

import cv2
import numpy as np
import pandas as pd
import re
import os
import os.path
import datetime
import csv
import time
import pprint

def generate_image_names(dir_path):
    image_names = []
    for root, dirs, files in os.walk(dir_path):
        files.sort()
        
        for file in files:
            # if file.startswith('2015-12-19_170'): # ensure we only grab CSV files
            if file.endswith('.jpg'): # ensure we only grab CSV files

                image_names.append(file)
                
    return image_names 

start_time = time.time()

#image_path = "/home/gene/test/BitTigerCapstone/Qinyuan/darkflow/sub_training/"
#out_path = "/home/gene/test/BitTigerCapstone/Qinyuan/darkflow/sub_training/crop-newRight/"

image_path = "/home/gene/Downloads/training/"
out_path = "/home/gene/test/BitTigerCapstone/Qinyuan/darkflow/newRight/"

images = generate_image_names(image_path)
count = 1
for image in images:
    
    print (str(count)+'-'+image_path+image)
    count = count + 1

    #    img = cv2.imread("/home/gene/test/BitTigerCapstone/Qinyuan/darkflow/sub_training/test.jpg")

    img = cv2.imread(image_path+image)

    #crop_img = img[y:y+h, x:x+w]
    #cv2.imshow("original",img)
    crop_img = img[0:480, 0:480]  #(0,0),(480,640) lefttop(y,x) #rightBottom (y+h,x+w)

    cv2.imwrite(out_path+"newRight-"+image, crop_img)

end_time = time.time() - start_time
print('[DONE] Elasped Time: {}'.format(end_time))
# Out:
# 1-/home/gene/Downloads/training/60091.jpg
# 2-/home/gene/Downloads/training/60092.jpg
# 3-/home/gene/Downloads/training/60093.jpg
# 4-/home/gene/Downloads/training/60094.jpg
# 5-/home/gene/Downloads/training/60095.jpg
# 6-/home/gene/Downloads/training/60096.jpg
# 7-/home/gene/Downloads/training/60097.jpg
# 8-/home/gene/Downloads/training/60098.jpg
# 9-/home/gene/Downloads/training/60099.jpg
# 10-/home/gene/Downloads/training/60100.jpg
# 11-/home/gene/Downloads/training/60101.jpg
# 12-/home/gene/Downloads/training/60102.jpg
# 13-/home/gene/Downloads/training/60103.jpg
# 14-/home/gene/Downloads/training/60104.jpg
# 15-/home/gene/Downloads/training/60105.jpg
# 16-/home/gene/Downloads/training/60106.jpg
# 17-/home/gene/Downloads/training/60107.jpg
# 18-/home/gene/Downloads/training/60108.jpg
# 19-/home/gene/Downloads/training/60109.jpg
# 20-/home/gene/Downloads/training/60110.jpg
# 21-/home/gene/Downloads/training/60111.jpg
# 22-/home/gene/Downloads/training/60112.jpg
# ...

# %%
#Formal crop-newLeft (160-640,0-480)

import cv2
import numpy as np
import pandas as pd
import re
import os
import os.path
import datetime
import csv
import time
import pprint

def generate_image_names(dir_path):
    image_names = []
    for root, dirs, files in os.walk(dir_path):
        files.sort()
        
        for file in files:
            if file.endswith('.jpg'): # ensure we only grab CSV files

                image_names.append(file)
                
    return image_names 

start_time = time.time()

#image_path = "/home/gene/test/BitTigerCapstone/Qinyuan/darkflow/sub_training/"
#out_path = "/home/gene/test/BitTigerCapstone/Qinyuan/darkflow/sub_training/crop-newRight/"

image_path = "/home/gene/Downloads/training/"
out_path = "/home/gene/test/BitTigerCapstone/Qinyuan/darkflow/newLeft/"

images = generate_image_names(image_path)
count = 1
for image in images:
    
    print (str(count)+'-'+image_path+image)
    count = count + 1

    #    img = cv2.imread("/home/gene/test/BitTigerCapstone/Qinyuan/darkflow/sub_training/test.jpg")

    img = cv2.imread(image_path+image)

    #crop_img = img[y:y+h, x:x+w]
    #cv2.imshow("original",img)
#    crop_img = img[0:480, 0:480]  #(0,0),(480,640) lefttop(y,x) #rightBottom (y+h,x+w)
    crop_img = img[0:480, 160:640]  #(0,0) lefttop(y,x) #rightBottom (y+h,x+w)

    cv2.imwrite(out_path+"newLeft-"+image, crop_img)

end_time = time.time() - start_time
print('[DONE] Elasped Time: {}'.format(end_time))
# Out:
# 1-/home/gene/Downloads/training/60091.jpg
# 2-/home/gene/Downloads/training/60092.jpg
# 3-/home/gene/Downloads/training/60093.jpg
# 4-/home/gene/Downloads/training/60094.jpg
# 5-/home/gene/Downloads/training/60095.jpg
# 6-/home/gene/Downloads/training/60096.jpg
# 7-/home/gene/Downloads/training/60097.jpg
# 8-/home/gene/Downloads/training/60098.jpg
# 9-/home/gene/Downloads/training/60099.jpg
# 10-/home/gene/Downloads/training/60100.jpg
# 11-/home/gene/Downloads/training/60101.jpg
# 12-/home/gene/Downloads/training/60102.jpg
# 13-/home/gene/Downloads/training/60103.jpg
# 14-/home/gene/Downloads/training/60104.jpg
# 15-/home/gene/Downloads/training/60105.jpg
# 16-/home/gene/Downloads/training/60106.jpg
# 17-/home/gene/Downloads/training/60107.jpg
# 18-/home/gene/Downloads/training/60108.jpg
# 19-/home/gene/Downloads/training/60109.jpg
# 20-/home/gene/Downloads/training/60110.jpg
# 21-/home/gene/Downloads/training/60111.jpg
# 22-/home/gene/Downloads/training/60112.jpg
# ...

# %%
#Formal crop-newRight (0-480,0-480)

import cv2
import numpy as np
import pandas as pd
import re
import os
import os.path
import datetime
import csv
import time
import pprint

def generate_image_names(dir_path):
    image_names = []
    for root, dirs, files in os.walk(dir_path):
        files.sort()
        
        for file in files:
            # if file.startswith('2015-12-19_170'): # ensure we only grab CSV files
            if file.endswith('.jpg'): # ensure we only grab CSV files

                image_names.append(file)
                
    return image_names 

start_time = time.time()

#image_path = "/home/gene/test/BitTigerCapstone/Qinyuan/darkflow/sub_training/"
#out_path = "/home/gene/test/BitTigerCapstone/Qinyuan/darkflow/sub_training/crop-newRight/"

image_path = "/home/gene/Downloads/training/"
out_path = "/home/gene/test/BitTigerCapstone/Qinyuan/darkflow/newRight/"

images = generate_image_names(image_path)
count = 1
for image in images:
    
    print (str(count)+'-'+image)
    count = count + 1
    
    img = cv2.imread("/home/gene/test/BitTigerCapstone/Qinyuan/darkflow/sub_training/test.jpg")
    #crop_img = img[y:y+h, x:x+w]
    #cv2.imshow("original",img)
    crop_img = img[0:480, 0:480]  #(0,0),(480,640) lefttop(y,x) #rightBottom (y+h,x+w)

    cv2.imwrite(out_path+"newRight-"+image, crop_img)

end_time = time.time() - start_time
print('[DONE] Elasped Time: {}'.format(end_time))

# %%
import cv2
import numpy as np
import pandas as pd
import re
import os
import os.path
import datetime
import csv
import time
import pprint

start_time = time.time()

out_path = "/home/gene/test/BitTigerCapstone/Qinyuan/darkflow/sub_training/crop-newRight/"

"""
def generate_image_names(dir_path):
    image_names = []
    for root, dirs, files in os.walk(dir_path):
        for file in files:

            # if file.startswith('2015-12-19_170'): # ensure we only grab CSV files
            if file.endswith('.jpg'): # ensure we only grab CSV files

                image_names.append(file)
                
return image_names 

image_path = "/home/gene/test/BitTigerCapstone/Qinyuan/darkflow/sub_training/"

images = generate_image_names(image_path)

for image in images:
    
    print (image)
    
"""    

img = cv2.imread("/home/gene/test/BitTigerCapstone/Qinyuan/darkflow/sub_training/test.jpg")
#crop_img = img[y:y+h, x:x+w]
#cv2.imshow("original",img)
crop_img = img[0:480, 160:640]  #(0,0) lefttop(y,x) #rightBottom (y+h,x+w)

cv2.imwrite(out_path+"cropped2.jpg", crop_img)
#cv2.imshow("cropped", crop_img)
#cv2.waitKey(0)

#/home/gene/Downloads/training/label.idl
#/home/gene/test/BitTigerCapstone/Qinyuan/darkflow/sub_training


end_time = time.time() - start_time
print('[DONE] Elasped Time: {}'.format(end_time))
# Out:
# [DONE] Elasped Time: 0.08901786804199219

# %%
import cv2
import numpy as np
import pandas as pd
import re
import os
import os.path
import datetime
import csv
import time
import pprint

start_time = time.time()
#print (start_time)

def generate_image_names(dir_path):
    image_names = []
    for root, dirs, files in os.walk(dir_path):
        for file in files:

            # if file.startswith('2015-12-19_170'): # ensure we only grab CSV files
            if file.endswith('.jpg'): # ensure we only grab CSV files

                image_names.append(file)
                
    return image_names 

image_path = "/home/gene/test/BitTigerCapstone/Qinyuan/darkflow/sub_training/"

images = generate_image_names(image_path)

for image in images:
    
    print (image)
    
"""    
img = cv2.imread("/home/gene/test/BitTigerCapstone/Qinyuan/darkflow/sub_training/test.jpg")
#crop_img = img[y:y+h, x:x+w]
cv2.imshow("original",img)
crop_img = img[0:480, 0:480]  #(0,0) lefttop(y,x) #rightBottom (y+h,x+w)
cv2.imshow("cropped", crop_img)
cv2.waitKey(0)
"""
#/home/gene/Downloads/training/label.idl
#/home/gene/test/BitTigerCapstone/Qinyuan/darkflow/sub_training


end_time = time.time() - start_time
print('[DONE] Elasped Time: {}'.format(end_time))
# Out:
# 60092.jpg
# 60093.jpg
# test.jpg
# 60095.jpg
# 60094.jpg
# 60091.jpg
# [DONE] Elasped Time: 0.0018916130065917969
